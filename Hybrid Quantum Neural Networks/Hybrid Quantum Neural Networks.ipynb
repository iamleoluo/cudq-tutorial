# %%
# Install the relevant packages.

! pip install numpy==1.24.4 matplotlib==3.8.4 torch==2.0.1+cu118 torchvision==0.15.2+cu118 scikit-learn==1.4.2 -q --extra-index-url https://download.pytorch.org/whl/cu126

# %%
# Import the relevant libraries


import matplotlib.pyplot as plt

import numpy as np

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn
import torchvision

from sklearn.model_selection import train_test_split


import cudaq
from cudaq import spin

torch.manual_seed(22)
cudaq.set_random_seed(44)

# %%
# Set CUDAQ and PyTorch to run on either CPU or GPU.

#device = torch.device('cpu')
#cudaq.set_target("qpp-cpu")

cudaq.set_target("nvidia")
device = torch.device("cuda:0")

# %%
def prepare_data(target_digits, sample_count, test_size):
    """Load and prepare the MNIST dataset to be used

    Args:
        target_digits (list): digits to perform classification of
        sample_count (int): total number of images to be used
        test_size (float): percentage of sample_count to be used as test set, the remainder is the training set

    Returns:
        dataset in train, test format with targets

    """

    transform = transforms.Compose(
        [transforms.ToTensor(),
         transforms.Normalize((0.1307), (0.3081))])

    dataset = datasets.MNIST("./data",
                             train=True,
                             download=True,
                             transform=transform)

    # Filter out the required labels.
    idx = (dataset.targets == target_digits[0]) | (dataset.targets
                                                   == target_digits[1])
    dataset.data = dataset.data[idx]
    dataset.targets = dataset.targets[idx]

    # Select a subset based on number of datapoints specified by sample_count.
    subset_indices = torch.randperm(dataset.data.size(0))[:sample_count]

    x = dataset.data[subset_indices].float().unsqueeze(1).to(device)

    y = dataset.targets[subset_indices].to(device).float().to(device)

    # Relabel the targets as a 0 or a 1.
    y = torch.where(y == min(target_digits), 0.0, 1.0)

    x_train, x_test, y_train, y_test = train_test_split(x,
                                                        y,
                                                        test_size=test_size /
                                                        100,
                                                        shuffle=True,
                                                        random_state=42)

    return x_train, x_test, y_train, y_test

# %%
# Classical parameters.

sample_count = 1000  # Total number of images to use.
target_digits = [5, 6]  # Hand written digits to classify.
test_size = 30  # Percentage of dataset to be used for testing.
classification_threshold = 0.9  # Classification boundary used to measure accuracy.
epochs = 500  # Number of epochs to train for.

# Quantum parmeters.

qubit_count = 5  # Number of qubits to use.
hamiltonian = spin.z(0)  # Measurement operator.
shift = torch.tensor(torch.pi / 2)  # Magnitude of parameter shift.

# %%
x_train, x_test, y_train, y_test = prepare_data(target_digits, sample_count,test_size)

# %%
# Plot some images from the training set to visualise.
if device != 'cpu':
    sample_to_plot = x_train[:10].to(torch.device('cpu'))
else:
    sample_to_plot = x_train[:10]

grid_img = torchvision.utils.make_grid(sample_to_plot,
                                       nrow=5,
                                       padding=3,
                                       normalize=True)
plt.imshow(grid_img.permute(1, 2, 0))
plt.axis('off')
plt.show()

# %%
class QuantumFunction(Function):
    """Allows the quantum circuit to input data, output expectation values
    and calculate gradients of variational parameters via finite difference"""

    def __init__(self, qubit_count: int, hamiltonian: cudaq.SpinOperator):
        """Define the quantum circuit in CUDA Quantum"""

        @cudaq.kernel
        def kernel(qubit_count: int, thetas: np.ndarray):

            qubits = cudaq.qvector(qubit_count)

            ry(thetas[0], qubits[0])
            rx(thetas[1], qubits[0])

        self.kernel = kernel
        self.qubit_count = qubit_count
        self.hamiltonian = hamiltonian


    def run(self, theta_vals: torch.tensor,) -> torch.tensor:
        """Excetute the quantum circuit to output an expectation value"""

        #If running on GPU, thetas is a torch.tensor that will live on GPU memory. The observe function calls a .tolist() method on inputs which moves thetas from GPU to CPU.

        qubit_count = [self.qubit_count for _ in range(theta_vals.shape[0])]

        results = cudaq.observe(self.kernel, self.hamiltonian, qubit_count,
                                theta_vals)

        exp_vals = [results[i].expectation() for i in range(len(results))]
        exp_vals = torch.Tensor(exp_vals).to(device)

        return exp_vals

    @staticmethod
    def forward(ctx, thetas: torch.tensor, quantum_circuit,
                shift) -> torch.tensor:

        # Save shift and quantum_circuit in context to use in backward.
        ctx.shift = shift
        ctx.quantum_circuit = quantum_circuit

        # Calculate expectation value.
        exp_vals = ctx.quantum_circuit.run(thetas).reshape(-1, 1)

        ctx.save_for_backward(thetas, exp_vals)

        return exp_vals

    @staticmethod
    def backward(ctx, grad_output):
        """Backward pass computation via finite difference"""

        thetas, _ = ctx.saved_tensors

        gradients = torch.zeros(thetas.shape, device=device)

        for i in range(thetas.shape[1]):

            thetas_plus = thetas.clone()
            thetas_plus[:, i] += ctx.shift
            exp_vals_plus = ctx.quantum_circuit.run(thetas_plus)

            thetas_minus = thetas.clone()
            thetas_minus[:, i] -= ctx.shift
            exp_vals_minus = ctx.quantum_circuit.run(thetas_minus)

            gradients[:, i] = (exp_vals_plus - exp_vals_minus) / (2 * ctx.shift)

        gradients = torch.mul(grad_output, gradients)

        return gradients, None, None

# %%
class QuantumLayer(nn.Module):
    """Encapsulates a quantum circuit into a quantum layer adhering PyTorch convention"""

    def __init__(self, qubit_count: int, hamiltonian, shift: torch.tensor):
        super(QuantumLayer, self).__init__()

        self.quantum_circuit = QuantumFunction(qubit_count, hamiltonian)
        self.shift = shift

    def forward(self, input):

        result = QuantumFunction.apply(input, self.quantum_circuit, self.shift)

        return result

# %%
class Hybrid_QNN(nn.Module):
    """Structure of the hybrid neural network with classical fully connected layers and quantum layers"""

    def __init__(self):
        super(Hybrid_QNN, self).__init__()

        self.fc1 = nn.Linear(28 * 28, 256)
        self.fc2 = nn.Linear(256, 128)
        self.dropout = nn.Dropout(0.25)

        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 32)
        self.fc5 = nn.Linear(32, 2)
        self.dropout = nn.Dropout(0.25)

        # The 2 outputs from PyTorch fc5 layer feed into the 2 variational gates in the quantum circuit.
        self.quantum = QuantumLayer(qubit_count, hamiltonian, shift)

    def forward(self, x):

        x = x.view(-1, 28 * 28)  # Turns images into vectors.

        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.dropout(x)

        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = torch.relu(self.fc5(x))
        x = self.dropout(x)

        # Quantum circuit outputs an expectation value which is fed into the sigmoid activation function to perform classification.
        x = torch.sigmoid(self.quantum(x))

        return x.view(-1)

# %%
def accuracy_score(y, y_hat, classification_threshold=0.5):
    # Compute accuracy directly on the GPU
    correct = (y == (y_hat >= classification_threshold)).float().sum()
    accuracy = correct / y.size(0)
    return accuracy

# %%
import time
from torch.utils.tensorboard import SummaryWriter
import torch.nn as nn
import torch.optim as optim
import torch


class HybridTrainer:
    def __init__(self, model, optimizer, loss_function, writer, device):
        """
        Initializes the trainer class.

        Args:
            model (torch.nn.Module): The PyTorch model to train and evaluate.
            optimizer (torch.optim.Optimizer): The optimizer for training.
            loss_function (torch.nn.Module): The loss function.
            writer (SummaryWriter): TensorBoard SummaryWriter instance.
            device (torch.device): Device to run the computations on (e.g., 'cpu' or 'cuda').
        """
        self.model = model
        self.optimizer = optimizer
        self.loss_function = loss_function
        self.writer = writer
        self.device = device

        self.training_cost = []
        self.testing_cost = []
        self.training_accuracy = []
        self.testing_accuracy = []

    def train(self, x_train, y_train, epoch):
        """
        Runs one epoch of training and logs metrics.

        Args:
            x_train (torch.Tensor): Training data.
            y_train (torch.Tensor): Training labels.
            epoch (int): Current epoch index.
        """
        train_start_time = time.time()

        self.model.train()
        self.optimizer.zero_grad()

        # Forward pass
        y_hat_train = self.model(x_train).to(self.device)
        train_cost = self.loss_function(y_hat_train, y_train).to(self.device)

        # Backward pass
        train_cost.backward()
        self.optimizer.step()

        # Compute accuracy
        accuracy = accuracy_score(y_train, y_hat_train)
        self.training_accuracy.append(accuracy)
        self.training_cost.append(train_cost.item())

        # Log training time
        train_elapsed_time = time.time() - train_start_time
        self.writer.add_scalar("Time(s) per epoch/Train", train_elapsed_time, epoch + 1)

        # Log training metrics to TensorBoard
        self.writer.add_scalar("Loss/Train", train_cost.item(), epoch + 1)
        self.writer.add_scalar("Accuracy/Train", accuracy, epoch + 1)
    def test(self, x_test, y_test, epoch):
        """
        Runs one evaluation step and logs metrics.

        Args:
            x_test (torch.Tensor): Testing data.
            y_test (torch.Tensor): Testing labels.
            epoch (int): Current epoch index.
        """
        eval_start_time = time.time()

        self.model.eval()
        with torch.no_grad():
            # Forward pass
            y_hat_test = self.model(x_test).to(self.device)
            test_cost = self.loss_function(y_hat_test, y_test).to(self.device)

            # Compute accuracy
            accuracy = accuracy_score(y_test, y_hat_test)
            self.testing_accuracy.append(accuracy)
            self.testing_cost.append(test_cost.item())

            # Log evaluation time
            eval_elapsed_time = time.time() - eval_start_time
            self.writer.add_scalar("Time(s) per epoch/Eval", eval_elapsed_time, epoch + 1)

            # Log testing metrics to TensorBoard
            self.writer.add_scalar("Loss/Test", test_cost.item(), epoch + 1)
            self.writer.add_scalar("Accuracy/Test", accuracy, epoch + 1)

# %%
import datetime

# Generate a unique log directory with timestamp
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# Set up the log directory with the current timestamp, sample_count,classification_threshold,epochs,qubit_count
log_dir = f"./runs/hybrid_qnn_training_{current_time}_samples_{sample_count}_threshold_{classification_threshold}_epochs_{epochs}_qubits_{qubit_count}"

writer = SummaryWriter(log_dir=log_dir)

# Initialize the trainer with your model, optimizer, loss function, etc.
hybrid_model = Hybrid_QNN().to(device)
trainer = HybridTrainer(
    model=hybrid_model,
    optimizer=optim.Adadelta(hybrid_model.parameters(), lr=0.001, weight_decay=0.8),
    loss_function=nn.BCELoss().to(device),
    writer=writer,
    device=device
)

# %%
for epoch in range(epochs):
    # Call the train and test methods for each epoch
    trainer.train(x_train, y_train, epoch)
    print(f"Epoch {epoch + 1}/{epochs} Training done.")
    trainer.test(x_test, y_test, epoch)
    print(f"Testing done.")

# Close the TensorBoard writer
writer.close()
# Out:
# Epoch 1/500 Training done.
# Testing done.
# Epoch 2/500 Training done.
# Testing done.
# Epoch 3/500 Training done.
# Testing done.
# Epoch 4/500 Training done.
# Testing done.
# Epoch 5/500 Training done.
# Testing done.
# Epoch 6/500 Training done.
# Testing done.
# Epoch 7/500 Training done.
# Testing done.
# Epoch 8/500 Training done.
# Testing done.
# Epoch 9/500 Training done.
# Testing done.
# Epoch 10/500 Training done.
# Testing done.
# Epoch 11/500 Training done.
# Testing done.
# Epoch 12/500 Training done.
# Testing done.
# Epoch 13/500 Training done.
# Testing done.
# Epoch 14/500 Training done.
# Testing done.
# Epoch 15/500 Training done.
# Testing done.
# Epoch 16/500 Training done.
# Testing done.
# Epoch 17/500 Training done.
# Testing done.
# Epoch 18/500 Training done.
# Testing done.
# Epoch 19/500 Training done.
# Testing done.
# Epoch 20/500 Training done.
# Testing done.
# Epoch 21/500 Training done.
# Testing done.
# Epoch 22/500 Training done.
# Testing done.
# Epoch 23/500 Training done.
# Testing done.
# Epoch 24/500 Training done.
# Testing done.
# Epoch 25/500 Training done.
# Testing done.
# Epoch 26/500 Training done.
# Testing done.
# Epoch 27/500 Training done.
# Testing done.
# Epoch 28/500 Training done.
# Testing done.
# Epoch 29/500 Training done.
# Testing done.
# Epoch 30/500 Training done.
# Testing done.
# Epoch 31/500 Training done.
# Testing done.
# Epoch 32/500 Training done.
# Testing done.
# Epoch 33/500 Training done.
# Testing done.
# Epoch 34/500 Training done.
# Testing done.
# Epoch 35/500 Training done.
# Testing done.
# Epoch 36/500 Training done.
# Testing done.
# Epoch 37/500 Training done.
# Testing done.
# Epoch 38/500 Training done.
# Testing done.
# Epoch 39/500 Training done.
# Testing done.
# Epoch 40/500 Training done.
# Testing done.
# Epoch 41/500 Training done.
# Testing done.
# Epoch 42/500 Training done.
# Testing done.
# Epoch 43/500 Training done.
# Testing done.
# Epoch 44/500 Training done.
# Testing done.
# Epoch 45/500 Training done.
# Testing done.
# Epoch 46/500 Training done.
# Testing done.
# Epoch 47/500 Training done.
# Testing done.
# Epoch 48/500 Training done.
# Testing done.
# Epoch 49/500 Training done.
# Testing done.
# Epoch 50/500 Training done.
# Testing done.
# Epoch 51/500 Training done.
# Testing done.
# Epoch 52/500 Training done.
# Testing done.
# Epoch 53/500 Training done.
# Testing done.
# Epoch 54/500 Training done.
# Testing done.
# Epoch 55/500 Training done.
# Testing done.
# Epoch 56/500 Training done.
# Testing done.
# Epoch 57/500 Training done.
# Testing done.
# Epoch 58/500 Training done.
# Testing done.
# Epoch 59/500 Training done.
# Testing done.
# Epoch 60/500 Training done.
# Testing done.
# Epoch 61/500 Training done.
# Testing done.
# Epoch 62/500 Training done.
# Testing done.
# Epoch 63/500 Training done.
# Testing done.
# Epoch 64/500 Training done.
# Testing done.
# Epoch 65/500 Training done.
# Testing done.
# Epoch 66/500 Training done.
# Testing done.
# Epoch 67/500 Training done.
# Testing done.
# Epoch 68/500 Training done.
# Testing done.
# Epoch 69/500 Training done.
# Testing done.
# Epoch 70/500 Training done.
# Testing done.
# Epoch 71/500 Training done.
# Testing done.
# Epoch 72/500 Training done.
# Testing done.
# Epoch 73/500 Training done.
# Testing done.
# Epoch 74/500 Training done.
# Testing done.
# Epoch 75/500 Training done.
# Testing done.
# Epoch 76/500 Training done.
# Testing done.
# Epoch 77/500 Training done.
# Testing done.
# Epoch 78/500 Training done.
# Testing done.
# Epoch 79/500 Training done.
# Testing done.
# Epoch 80/500 Training done.
# Testing done.
# Epoch 81/500 Training done.
# Testing done.
# Epoch 82/500 Training done.
# Testing done.
# Epoch 83/500 Training done.
# Testing done.
# Epoch 84/500 Training done.
# Testing done.
# Epoch 85/500 Training done.
# Testing done.
# Epoch 86/500 Training done.
# Testing done.
# Epoch 87/500 Training done.
# Testing done.
# Epoch 88/500 Training done.
# Testing done.
# Epoch 89/500 Training done.
# Testing done.
# Epoch 90/500 Training done.
# Testing done.
# Epoch 91/500 Training done.
# Testing done.
# Epoch 92/500 Training done.
# Testing done.
# Epoch 93/500 Training done.
# Testing done.
# Epoch 94/500 Training done.
# Testing done.
# Epoch 95/500 Training done.
# Testing done.
# Epoch 96/500 Training done.
# Testing done.
# Epoch 97/500 Training done.
# Testing done.
# Epoch 98/500 Training done.
# Testing done.
# Epoch 99/500 Training done.
# Testing done.
# Epoch 100/500 Training done.
# Testing done.
# Epoch 101/500 Training done.
# Testing done.
# Epoch 102/500 Training done.
# Testing done.
# Epoch 103/500 Training done.
# Testing done.
# Epoch 104/500 Training done.
# Testing done.
# Epoch 105/500 Training done.
# Testing done.
# Epoch 106/500 Training done.
# Testing done.
# Epoch 107/500 Training done.
# Testing done.
# Epoch 108/500 Training done.
# Testing done.
# Epoch 109/500 Training done.
# Testing done.
# Epoch 110/500 Training done.
# Testing done.
# Epoch 111/500 Training done.
# Testing done.
# Epoch 112/500 Training done.
# Testing done.
# Epoch 113/500 Training done.
# Testing done.
# Epoch 114/500 Training done.
# Testing done.
# Epoch 115/500 Training done.
# Testing done.
# Epoch 116/500 Training done.
# Testing done.
# Epoch 117/500 Training done.
# Testing done.
# Epoch 118/500 Training done.
# Testing done.
# Epoch 119/500 Training done.
# Testing done.
# Epoch 120/500 Training done.
# Testing done.
# Epoch 121/500 Training done.
# Testing done.
# Epoch 122/500 Training done.
# Testing done.
# Epoch 123/500 Training done.
# Testing done.
# Epoch 124/500 Training done.
# Testing done.
# Epoch 125/500 Training done.
# Testing done.
# Epoch 126/500 Training done.
# Testing done.
# Epoch 127/500 Training done.
# Testing done.
# Epoch 128/500 Training done.
# Testing done.
# Epoch 129/500 Training done.
# Testing done.
# Epoch 130/500 Training done.
# Testing done.
# Epoch 131/500 Training done.
# Testing done.
# Epoch 132/500 Training done.
# Testing done.
# Epoch 133/500 Training done.
# Testing done.
# Epoch 134/500 Training done.
# Testing done.
# Epoch 135/500 Training done.
# Testing done.
# Epoch 136/500 Training done.
# Testing done.
# Epoch 137/500 Training done.
# Testing done.
# Epoch 138/500 Training done.
# Testing done.
# Epoch 139/500 Training done.
# Testing done.
# Epoch 140/500 Training done.
# Testing done.
# Epoch 141/500 Training done.
# Testing done.
# Epoch 142/500 Training done.
# Testing done.
# Epoch 143/500 Training done.
# Testing done.
# Epoch 144/500 Training done.
# Testing done.
# Epoch 145/500 Training done.
# Testing done.
# Epoch 146/500 Training done.
# Testing done.
# Epoch 147/500 Training done.
# Testing done.
# Epoch 148/500 Training done.
# Testing done.
# Epoch 149/500 Training done.
# Testing done.
# Epoch 150/500 Training done.
# Testing done.
# Epoch 151/500 Training done.
# Testing done.
# Epoch 152/500 Training done.
# Testing done.
# Epoch 153/500 Training done.
# Testing done.
# Epoch 154/500 Training done.
# Testing done.
# Epoch 155/500 Training done.
# Testing done.
# Epoch 156/500 Training done.
# Testing done.
# Epoch 157/500 Training done.
# Testing done.
# Epoch 158/500 Training done.
# Testing done.
# Epoch 159/500 Training done.
# Testing done.
# Epoch 160/500 Training done.
# Testing done.
# Epoch 161/500 Training done.
# Testing done.
# Epoch 162/500 Training done.
# Testing done.
# Epoch 163/500 Training done.
# Testing done.
# Epoch 164/500 Training done.
# Testing done.
# Epoch 165/500 Training done.
# Testing done.
# Epoch 166/500 Training done.
# Testing done.
# Epoch 167/500 Training done.
# Testing done.
# Epoch 168/500 Training done.
# Testing done.
# Epoch 169/500 Training done.
# Testing done.
# Epoch 170/500 Training done.
# Testing done.
# Epoch 171/500 Training done.
# Testing done.
# Epoch 172/500 Training done.
# Testing done.
# Epoch 173/500 Training done.
# Testing done.
# Epoch 174/500 Training done.
# Testing done.
# Epoch 175/500 Training done.
# Testing done.
# Epoch 176/500 Training done.
# Testing done.
# Epoch 177/500 Training done.
# Testing done.
# Epoch 178/500 Training done.
# Testing done.
# Epoch 179/500 Training done.
# Testing done.
# Epoch 180/500 Training done.
# Testing done.
# Epoch 181/500 Training done.
# Testing done.
# Epoch 182/500 Training done.
# Testing done.
# Epoch 183/500 Training done.
# Testing done.
# Epoch 184/500 Training done.
# Testing done.
# Epoch 185/500 Training done.
# Testing done.
# Epoch 186/500 Training done.
# Testing done.
# Epoch 187/500 Training done.
# Testing done.
# Epoch 188/500 Training done.
# Testing done.
# Epoch 189/500 Training done.
# Testing done.
# Epoch 190/500 Training done.
# Testing done.
# Epoch 191/500 Training done.
# Testing done.
# Epoch 192/500 Training done.
# Testing done.
# Epoch 193/500 Training done.
# Testing done.
# Epoch 194/500 Training done.
# Testing done.
# Epoch 195/500 Training done.
# Testing done.
# Epoch 196/500 Training done.
# Testing done.
# Epoch 197/500 Training done.
# Testing done.
# Epoch 198/500 Training done.
# Testing done.
# Epoch 199/500 Training done.
# Testing done.
# Epoch 200/500 Training done.
# Testing done.
# Epoch 201/500 Training done.
# Testing done.
# Epoch 202/500 Training done.
# Testing done.
# Epoch 203/500 Training done.
# Testing done.
# Epoch 204/500 Training done.
# Testing done.
# Epoch 205/500 Training done.
# Testing done.
# Epoch 206/500 Training done.
# Testing done.
# Epoch 207/500 Training done.
# Testing done.
# Epoch 208/500 Training done.
# Testing done.
# Epoch 209/500 Training done.
# Testing done.
# Epoch 210/500 Training done.
# Testing done.
# Epoch 211/500 Training done.
# Testing done.
# Epoch 212/500 Training done.
# Testing done.
# Epoch 213/500 Training done.
# Testing done.
# Epoch 214/500 Training done.
# Testing done.
# Epoch 215/500 Training done.
# Testing done.
# Epoch 216/500 Training done.
# Testing done.
# Epoch 217/500 Training done.
# Testing done.
# Epoch 218/500 Training done.
# Testing done.
# Epoch 219/500 Training done.
# Testing done.
# Epoch 220/500 Training done.
# Testing done.
# Epoch 221/500 Training done.
# Testing done.
# Epoch 222/500 Training done.
# Testing done.
# Epoch 223/500 Training done.
# Testing done.
# Epoch 224/500 Training done.
# Testing done.
# Epoch 225/500 Training done.
# Testing done.
# Epoch 226/500 Training done.
# Testing done.
# Epoch 227/500 Training done.
# Testing done.
# Epoch 228/500 Training done.
# Testing done.
# Epoch 229/500 Training done.
# Testing done.
# Epoch 230/500 Training done.
# Testing done.
# Epoch 231/500 Training done.
# Testing done.
# Epoch 232/500 Training done.
# Testing done.
# Epoch 233/500 Training done.
# Testing done.
# Epoch 234/500 Training done.
# Testing done.
# Epoch 235/500 Training done.
# Testing done.
# Epoch 236/500 Training done.
# Testing done.
# Epoch 237/500 Training done.
# Testing done.
# Epoch 238/500 Training done.
# Testing done.
# Epoch 239/500 Training done.
# Testing done.
# Epoch 240/500 Training done.
# Testing done.
# Epoch 241/500 Training done.
# Testing done.
# Epoch 242/500 Training done.
# Testing done.
# Epoch 243/500 Training done.
# Testing done.
# Epoch 244/500 Training done.
# Testing done.
# Epoch 245/500 Training done.
# Testing done.
# Epoch 246/500 Training done.
# Testing done.
# Epoch 247/500 Training done.
# Testing done.
# Epoch 248/500 Training done.
# Testing done.
# Epoch 249/500 Training done.
# Testing done.
# Epoch 250/500 Training done.
# Testing done.
# Epoch 251/500 Training done.
# Testing done.
# Epoch 252/500 Training done.
# Testing done.
# Epoch 253/500 Training done.
# Testing done.
# Epoch 254/500 Training done.
# Testing done.
# Epoch 255/500 Training done.
# Testing done.
# Epoch 256/500 Training done.
# Testing done.
# Epoch 257/500 Training done.
# Testing done.
# Epoch 258/500 Training done.
# Testing done.
# Epoch 259/500 Training done.
# Testing done.
# Epoch 260/500 Training done.
# Testing done.
# Epoch 261/500 Training done.
# Testing done.
# Epoch 262/500 Training done.
# Testing done.
# Epoch 263/500 Training done.
# Testing done.
# Epoch 264/500 Training done.
# Testing done.
# Epoch 265/500 Training done.
# Testing done.
# Epoch 266/500 Training done.
# Testing done.
# Epoch 267/500 Training done.
# Testing done.
# Epoch 268/500 Training done.
# Testing done.
# Epoch 269/500 Training done.
# Testing done.
# Epoch 270/500 Training done.
# Testing done.
# Epoch 271/500 Training done.
# Testing done.
# Epoch 272/500 Training done.
# Testing done.
# Epoch 273/500 Training done.
# Testing done.
# Epoch 274/500 Training done.
# Testing done.
# Epoch 275/500 Training done.
# Testing done.
# Epoch 276/500 Training done.
# Testing done.
# Epoch 277/500 Training done.
# Testing done.
# Epoch 278/500 Training done.
# Testing done.
# Epoch 279/500 Training done.
# Testing done.
# Epoch 280/500 Training done.
# Testing done.
# Epoch 281/500 Training done.
# Testing done.
# Epoch 282/500 Training done.
# Testing done.
# Epoch 283/500 Training done.
# Testing done.
# Epoch 284/500 Training done.
# Testing done.
# Epoch 285/500 Training done.
# Testing done.
# Epoch 286/500 Training done.
# Testing done.
# Epoch 287/500 Training done.
# Testing done.
# Epoch 288/500 Training done.
# Testing done.
# Epoch 289/500 Training done.
# Testing done.
# Epoch 290/500 Training done.
# Testing done.
# Epoch 291/500 Training done.
# Testing done.
# Epoch 292/500 Training done.
# Testing done.
# Epoch 293/500 Training done.
# Testing done.
# Epoch 294/500 Training done.
# Testing done.
# Epoch 295/500 Training done.
# Testing done.
# Epoch 296/500 Training done.
# Testing done.
# Epoch 297/500 Training done.
# Testing done.
# Epoch 298/500 Training done.
# Testing done.
# Epoch 299/500 Training done.
# Testing done.
# Epoch 300/500 Training done.
# Testing done.
# Epoch 301/500 Training done.
# Testing done.
# Epoch 302/500 Training done.
# Testing done.
# Epoch 303/500 Training done.
# Testing done.
# Epoch 304/500 Training done.
# Testing done.
# Epoch 305/500 Training done.
# Testing done.
# Epoch 306/500 Training done.
# Testing done.
# Epoch 307/500 Training done.
# Testing done.
# Epoch 308/500 Training done.
# Testing done.
# Epoch 309/500 Training done.
# Testing done.
# Epoch 310/500 Training done.
# Testing done.
# Epoch 311/500 Training done.
# Testing done.
# Epoch 312/500 Training done.
# Testing done.
# Epoch 313/500 Training done.
# Testing done.
# Epoch 314/500 Training done.
# Testing done.
# Epoch 315/500 Training done.
# Testing done.
# Epoch 316/500 Training done.
# Testing done.
# Epoch 317/500 Training done.
# Testing done.
# Epoch 318/500 Training done.
# Testing done.
# Epoch 319/500 Training done.
# Testing done.
# Epoch 320/500 Training done.
# Testing done.
# Epoch 321/500 Training done.
# Testing done.
# Epoch 322/500 Training done.
# Testing done.
# Epoch 323/500 Training done.
# Testing done.
# Epoch 324/500 Training done.
# Testing done.
# Epoch 325/500 Training done.
# Testing done.
# Epoch 326/500 Training done.
# Testing done.
# Epoch 327/500 Training done.
# Testing done.
# Epoch 328/500 Training done.
# Testing done.
# Epoch 329/500 Training done.
# Testing done.
# Epoch 330/500 Training done.
# Testing done.
# Epoch 331/500 Training done.
# Testing done.
# Epoch 332/500 Training done.
# Testing done.
# Epoch 333/500 Training done.
# Testing done.
# Epoch 334/500 Training done.
# Testing done.
# Epoch 335/500 Training done.
# Testing done.
# Epoch 336/500 Training done.
# Testing done.
# Epoch 337/500 Training done.
# Testing done.
# Epoch 338/500 Training done.
# Testing done.
# Epoch 339/500 Training done.
# Testing done.
# Epoch 340/500 Training done.
# Testing done.
# Epoch 341/500 Training done.
# Testing done.
# Epoch 342/500 Training done.
# Testing done.
# Epoch 343/500 Training done.
# Testing done.
# Epoch 344/500 Training done.
# Testing done.
# Epoch 345/500 Training done.
# Testing done.
# Epoch 346/500 Training done.
# Testing done.
# Epoch 347/500 Training done.
# Testing done.
# Epoch 348/500 Training done.
# Testing done.
# Epoch 349/500 Training done.
# Testing done.
# Epoch 350/500 Training done.
# Testing done.
# Epoch 351/500 Training done.
# Testing done.
# Epoch 352/500 Training done.
# Testing done.
# Epoch 353/500 Training done.
# Testing done.
# Epoch 354/500 Training done.
# Testing done.
# Epoch 355/500 Training done.
# Testing done.
# Epoch 356/500 Training done.
# Testing done.
# Epoch 357/500 Training done.
# Testing done.
# Epoch 358/500 Training done.
# Testing done.
# Epoch 359/500 Training done.
# Testing done.
# Epoch 360/500 Training done.
# Testing done.
# Epoch 361/500 Training done.
# Testing done.
# Epoch 362/500 Training done.
# Testing done.
# Epoch 363/500 Training done.
# Testing done.
# Epoch 364/500 Training done.
# Testing done.
# Epoch 365/500 Training done.
# Testing done.
# Epoch 366/500 Training done.
# Testing done.
# Epoch 367/500 Training done.
# Testing done.
# Epoch 368/500 Training done.
# Testing done.
# Epoch 369/500 Training done.
# Testing done.
# Epoch 370/500 Training done.
# Testing done.
# Epoch 371/500 Training done.
# Testing done.
# Epoch 372/500 Training done.
# Testing done.
# Epoch 373/500 Training done.
# Testing done.
# Epoch 374/500 Training done.
# Testing done.
# Epoch 375/500 Training done.
# Testing done.
# Epoch 376/500 Training done.
# Testing done.
# Epoch 377/500 Training done.
# Testing done.
# Epoch 378/500 Training done.
# Testing done.
# Epoch 379/500 Training done.
# Testing done.
# Epoch 380/500 Training done.
# Testing done.
# Epoch 381/500 Training done.
# Testing done.
# Epoch 382/500 Training done.
# Testing done.
# Epoch 383/500 Training done.
# Testing done.
# Epoch 384/500 Training done.
# Testing done.
# Epoch 385/500 Training done.
# Testing done.
# Epoch 386/500 Training done.
# Testing done.
# Epoch 387/500 Training done.
# Testing done.
# Epoch 388/500 Training done.
# Testing done.
# Epoch 389/500 Training done.
# Testing done.
# Epoch 390/500 Training done.
# Testing done.
# Epoch 391/500 Training done.
# Testing done.
# Epoch 392/500 Training done.
# Testing done.
# Epoch 393/500 Training done.
# Testing done.
# Epoch 394/500 Training done.
# Testing done.
# Epoch 395/500 Training done.
# Testing done.
# Epoch 396/500 Training done.
# Testing done.
# Epoch 397/500 Training done.
# Testing done.
# Epoch 398/500 Training done.
# Testing done.
# Epoch 399/500 Training done.
# Testing done.
# Epoch 400/500 Training done.
# Testing done.
# Epoch 401/500 Training done.
# Testing done.
# Epoch 402/500 Training done.
# Testing done.
# Epoch 403/500 Training done.
# Testing done.
# Epoch 404/500 Training done.
# Testing done.
# Epoch 405/500 Training done.
# Testing done.
# Epoch 406/500 Training done.
# Testing done.
# Epoch 407/500 Training done.
# Testing done.
# Epoch 408/500 Training done.
# Testing done.
# Epoch 409/500 Training done.
# Testing done.
# Epoch 410/500 Training done.
# Testing done.
# Epoch 411/500 Training done.
# Testing done.
# Epoch 412/500 Training done.
# Testing done.
# Epoch 413/500 Training done.
# Testing done.
# Epoch 414/500 Training done.
# Testing done.
# Epoch 415/500 Training done.
# Testing done.
# Epoch 416/500 Training done.
# Testing done.
# Epoch 417/500 Training done.
# Testing done.
# Epoch 418/500 Training done.
# Testing done.
# Epoch 419/500 Training done.
# Testing done.
# Epoch 420/500 Training done.
# Testing done.
# Epoch 421/500 Training done.
# Testing done.
# Epoch 422/500 Training done.
# Testing done.
# Epoch 423/500 Training done.
# Testing done.
# Epoch 424/500 Training done.
# Testing done.
# Epoch 425/500 Training done.
# Testing done.
# Epoch 426/500 Training done.
# Testing done.
# Epoch 427/500 Training done.
# Testing done.
# Epoch 428/500 Training done.
# Testing done.
# Epoch 429/500 Training done.
# Testing done.
# Epoch 430/500 Training done.
# Testing done.
# Epoch 431/500 Training done.
# Testing done.
# Epoch 432/500 Training done.
# Testing done.
# Epoch 433/500 Training done.
# Testing done.
# Epoch 434/500 Training done.
# Testing done.
# Epoch 435/500 Training done.
# Testing done.
# Epoch 436/500 Training done.
# Testing done.
# Epoch 437/500 Training done.
# Testing done.
# Epoch 438/500 Training done.
# Testing done.
# Epoch 439/500 Training done.
# Testing done.
# Epoch 440/500 Training done.
# Testing done.
# Epoch 441/500 Training done.
# Testing done.
# Epoch 442/500 Training done.
# Testing done.
# Epoch 443/500 Training done.
# Testing done.
# Epoch 444/500 Training done.
# Testing done.
# Epoch 445/500 Training done.
# Testing done.
# Epoch 446/500 Training done.
# Testing done.
# Epoch 447/500 Training done.
# Testing done.
# Epoch 448/500 Training done.
# Testing done.
# Epoch 449/500 Training done.
# Testing done.
# Epoch 450/500 Training done.
# Testing done.
# Epoch 451/500 Training done.
# Testing done.
# Epoch 452/500 Training done.
# Testing done.
# Epoch 453/500 Training done.
# Testing done.
# Epoch 454/500 Training done.
# Testing done.
# Epoch 455/500 Training done.
# Testing done.
# Epoch 456/500 Training done.
# Testing done.
# Epoch 457/500 Training done.
# Testing done.
# Epoch 458/500 Training done.
# Testing done.
# Epoch 459/500 Training done.
# Testing done.
# Epoch 460/500 Training done.
# Testing done.
# Epoch 461/500 Training done.
# Testing done.
# Epoch 462/500 Training done.
# Testing done.
# Epoch 463/500 Training done.
# Testing done.
# Epoch 464/500 Training done.
# Testing done.
# Epoch 465/500 Training done.
# Testing done.
# Epoch 466/500 Training done.
# Testing done.
# Epoch 467/500 Training done.
# Testing done.
# Epoch 468/500 Training done.
# Testing done.
# Epoch 469/500 Training done.
# Testing done.
# Epoch 470/500 Training done.
# Testing done.
# Epoch 471/500 Training done.
# Testing done.
# Epoch 472/500 Training done.
# Testing done.
# Epoch 473/500 Training done.
# Testing done.
# Epoch 474/500 Training done.
# Testing done.
# Epoch 475/500 Training done.
# Testing done.
# Epoch 476/500 Training done.
# Testing done.
# Epoch 477/500 Training done.
# Testing done.
# Epoch 478/500 Training done.
# Testing done.
# Epoch 479/500 Training done.
# Testing done.
# Epoch 480/500 Training done.
# Testing done.
# Epoch 481/500 Training done.
# Testing done.
# Epoch 482/500 Training done.
# Testing done.
# Epoch 483/500 Training done.
# Testing done.
# Epoch 484/500 Training done.
# Testing done.
# Epoch 485/500 Training done.
# Testing done.
# Epoch 486/500 Training done.
# Testing done.
# Epoch 487/500 Training done.
# Testing done.
# Epoch 488/500 Training done.
# Testing done.
# Epoch 489/500 Training done.
# Testing done.
# Epoch 490/500 Training done.
# Testing done.
# Epoch 491/500 Training done.
# Testing done.
# Epoch 492/500 Training done.
# Testing done.
# Epoch 493/500 Training done.
# Testing done.
# Epoch 494/500 Training done.
# Testing done.
# Epoch 495/500 Training done.
# Testing done.
# Epoch 496/500 Training done.
# Testing done.
# Epoch 497/500 Training done.
# Testing done.
# Epoch 498/500 Training done.
# Testing done.
# Epoch 499/500 Training done.
# Testing done.
# Epoch 500/500 Training done.
# Testing done.

# %%
'''from torch.utils.tensorboard import SummaryWriter

# Initialize TensorBoard writer
writer = SummaryWriter(log_dir="./runs/hybrid_qnn_training")

# Existing code
hybrid_model = Hybrid_QNN().to(device)

optimizer = optim.Adadelta(hybrid_model.parameters(),
                           lr=0.001,
                           weight_decay=0.8)

loss_function = nn.BCELoss().to(device)

training_cost = []
testing_cost = []
training_accuracy = []
testing_accuracy = []

hybrid_model.train()


import time
for epoch in range(epochs):

    train_start_time = time.time()

    optimizer.zero_grad()

    y_hat_train = hybrid_model(x_train).to(device)

    train_cost = loss_function(y_hat_train, y_train).to(device)

    train_cost.backward()

    optimizer.step()

    training_accuracy.append(accuracy_score(y_train, y_hat_train))
    training_cost.append(train_cost.item())

    train_elapsed_time = time.time() - train_start_time
    writer.add_scalar("Time/Train", train_elapsed_time, epoch + 1)

    writer.add_scalar("Loss/Train", train_cost.item(), epoch + 1)
    writer.add_scalar("Accuracy/Train", training_accuracy[-1], epoch + 1)

    eval_start_time = time.time()

    hybrid_model.eval()
    with torch.no_grad():

        y_hat_test = hybrid_model(x_test).to(device)

        test_cost = loss_function(y_hat_test, y_test).to(device)

        testing_accuracy.append(accuracy_score(y_test, y_hat_test))
        testing_cost.append(test_cost.item())


        # Log testing metrics to TensorBoard
        writer.add_scalar("Loss/Test", test_cost.item(), epoch + 1)
        writer.add_scalar("Accuracy/Test", testing_accuracy[-1], epoch + 1)

# Close TensorBoard writer
writer.close()'''
# Out:
# 'from torch.utils.tensorboard import SummaryWriter\n\n# Initialize TensorBoard writer\nwriter = SummaryWriter(log_dir="./runs/hybrid_qnn_training")\n\n# Existing code\nhybrid_model = Hybrid_QNN().to(device)\n\noptimizer = optim.Adadelta(hybrid_model.parameters(),\n                           lr=0.001,\n                           weight_decay=0.8)\n\nloss_function = nn.BCELoss().to(device)\n\ntraining_cost = []\ntesting_cost = []\ntraining_accuracy = []\ntesting_accuracy = []\n\nhybrid_model.train()\n\n\nimport time\nfor epoch in range(epochs):\n\n    train_start_time = time.time()\n\n    optimizer.zero_grad()\n\n    y_hat_train = hybrid_model(x_train).to(device)\n\n    train_cost = loss_function(y_hat_train, y_train).to(device)\n\n    train_cost.backward()\n\n    optimizer.step()\n\n    training_accuracy.append(accuracy_score(y_train, y_hat_train))\n    training_cost.append(train_cost.item())\n\n    train_elapsed_time = time.time() - train_start_time\n    writer.add_scalar("Time/Train", train_elapsed_time, epoch + 1)\n\n    writer.add_scalar("Loss/Train", train_cost.item(), epoch + 1)\n    writer.add_scalar("Accuracy/Train", training_accuracy[-1], epoch + 1)\n\n    eval_start_time = time.time()\n\n    hybrid_model.eval()\n    with torch.no_grad():\n\n        y_hat_test = hybrid_model(x_test).to(device)\n\n        test_cost = loss_function(y_hat_test, y_test).to(device)\n\n        testing_accuracy.append(accuracy_score(y_test, y_hat_test))\n        testing_cost.append(test_cost.item())\n\n\n        # Log testing metrics to TensorBoard\n        writer.add_scalar("Loss/Test", test_cost.item(), epoch + 1)\n        writer.add_scalar("Accuracy/Test", testing_accuracy[-1], epoch + 1)\n\n# Close TensorBoard writer\nwriter.close()'

# %%
training_cost = trainer.training_cost
testing_cost = trainer.testing_cost
training_accuracy = trainer.training_accuracy
testing_accuracy = trainer.testing_accuracy

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(training_cost, label='Train')
plt.plot(testing_cost, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Cost')
plt.legend()

plt.subplot(1, 2, 2)
training_accuracy = np.array(torch.tensor(training_accuracy).cpu())
testing_accuracy = np.array(torch.tensor(testing_accuracy).cpu())
plt.plot(training_accuracy, label='Train')
plt.plot(testing_accuracy, label='Test')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
